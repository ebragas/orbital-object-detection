# %%
from PIL import Image, ImageDraw

# %%
image = Image.open('../../data/scenes/sfbay_1.png')
image.crop((1150, 50, 1230, 130))
# Out:
# <PIL.Image.Image image mode=RGBA size=80x80 at 0x1068421D0>

# %%
image.crop((850, 475, 930, 555))
# Out:
# <PIL.Image.Image image mode=RGBA size=80x80 at 0x1054CDE48>

# %%
coords = [
    (1150, 50, 1230, 130),
    (850, 475, 930, 555),
    (950, 700, 1030, 780),
    (1300, 1650, 1380, 1730),
    (1325, 1650, 1405, 1730)
]

annotated = image.copy()
draw = ImageDraw.Draw(annotated)

for coord in coords:
    draw.rectangle(coord, outline='red', width=3)
    
annotated
